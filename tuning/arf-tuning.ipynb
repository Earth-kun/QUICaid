# %%
from skmultiflow.meta import AdaptiveRandomForestClassifier

from skmultiflow.data import FileStream             # create stream from file
from sklearn.model_selection import ParameterGrid   # hyperparameter combinations

from prequential import run_prequential

# %%
data_loader = FileStream(filepath='../out.csv')

# %%
ref_sample, _ = data_loader.next_sample(50)
data_loader.reset()


print(ref_sample)
# Out:
# [[5.4865e+04 3.0000e+00 2.0000e+00 ... 0.0000e+00 0.0000e+00 0.0000e+00]
#  [5.5054e+04 1.0900e+02 1.0000e+00 ... 0.0000e+00 0.0000e+00 0.0000e+00]
#  [5.5055e+04 5.2000e+01 1.0000e+00 ... 0.0000e+00 0.0000e+00 0.0000e+00]
#  ...
#  [8.6900e+03 1.7000e+01 1.0000e+00 ... 0.0000e+00 0.0000e+00 0.0000e+00]
#  [8.6940e+03 1.2300e+02 1.0000e+00 ... 0.0000e+00 0.0000e+00 0.0000e+00]
#  [5.7683e+04 4.0000e+00 2.0000e+00 ... 0.0000e+00 0.0000e+00 0.0000e+00]]

# %%
parameters = {
    'n_estimators': [3, 6, 9],             # default=10
    'max_features': ['None'],                  # default=auto
    'drift_detection_method': ['ADWIN(0.001)'],   
    'grace_period': [10, 25, 50, 100, 200],    # default=50
    'split_criterion': ['info_gain', 'gini'],  # default=info_gain
    'split_confidence': [0.01, 0.05, 0.1, 0.2, 0.25, 0.001],     # default=0.01
    'tie_threshold': [0.01, 0.05, 0.1, 0.2, 0.001],        # default=0.05
    'leaf_prediction': ['mc', 'nb', 'nba'],    # default=nba
}

arf_grid = ParameterGrid(parameters)

# %%
best_params = None
best_score = 0
best_metrics = []

results = []

for params in arf_grid:
    print(f"Evaluating parameters: {params}")
    data_loader.restart()
    train_data, _ = data_loader.next_sample(200)
    test_data, _ = data_loader.next_sample(200)

    # Update the classifier with the current parameters
    arf = AdaptiveRandomForestClassifier(**params)

    accuracy, precision, recall, f1, avg_processing_time = run_prequential(
        classifier=arf,
        stream=data_loader,
        feature_selector=None,  # No feature selector
        n_pretrain=200
    )
    print(f"Accuracy: {accuracy:.8f}, Precision: {precision:.8f}, Recall: {recall:.8f}, F1: {f1:.8f}")
    print(f"Average processing time: {avg_processing_time}")
    
    avg_score = (accuracy + precision + recall + f1) / 4
    
    results.append({
        **params,
        'accuracy': accuracy,
        'precision': precision,
        'recall': recall,
        'f1': f1,
        'avg_score': avg_score,
        'avg_processing_time': avg_processing_time
    })

    if (accuracy + precision + recall + f1) / 4 > best_score:
        best_params = params
        best_score = (accuracy + precision + recall + f1) / 4
        best_metrics = [accuracy, precision, recall, f1]
# Out:
# Evaluating parameters: {'binary_split': False, 'disable_weighted_vote': False, 'drift_detection_method': 'None', 'grace_period': 50, 'lambda_value': 6, 'leaf_prediction': 'mc', 'max_byte_size': 33554432, 'max_features': 'auto', 'memory_estimate_period': 2000000, 'n_estimators': 10, 'nb_threshold': 0, 'no_preprune': False, 'nominal_attributes': None, 'performance_metric': 'acc', 'random_state': None, 'remove_poor_atts': False, 'split_confidence': 0.01, 'split_criterion': 'info_gain', 'stop_mem_management': False, 'tie_threshold': 0.05, 'warning_detection_method': 'None'}
# Accuracy: 0.99770000, Precision: 0.99740303, Recall: 0.99777917, F1: 0.99759107
# Evaluating parameters: {'binary_split': False, 'disable_weighted_vote': False, 'drift_detection_method': 'None', 'grace_period': 50, 'lambda_value': 6, 'leaf_prediction': 'mc', 'max_byte_size': 33554432, 'max_features': 'auto', 'memory_estimate_period': 2000000, 'n_estimators': 10, 'nb_threshold': 0, 'no_preprune': False, 'nominal_attributes': None, 'performance_metric': 'acc', 'random_state': None, 'remove_poor_atts': False, 'split_confidence': 0.01, 'split_criterion': 'info_gain', 'stop_mem_management': False, 'tie_threshold': 0.1, 'warning_detection_method': 'None'}
# Accuracy: 0.99832000, Precision: 0.99857436, Recall: 0.99790488, F1: 0.99823951
# Evaluating parameters: {'binary_split': False, 'disable_weighted_vote': False, 'drift_detection_method': 'None', 'grace_period': 50, 'lambda_value': 6, 'leaf_prediction': 'mc', 'max_byte_size': 33554432, 'max_features': 'auto', 'memory_estimate_period': 2000000, 'n_estimators': 10, 'nb_threshold': 0, 'no_preprune': False, 'nominal_attributes': None, 'performance_metric': 'acc', 'random_state': None, 'remove_poor_atts': False, 'split_confidence': 0.01, 'split_criterion': 'gini', 'stop_mem_management': False, 'tie_threshold': 0.05, 'warning_detection_method': 'None'}
# Accuracy: 0.99858000, Precision: 0.99890967, Recall: 0.99811439, F1: 0.99851187
# Evaluating parameters: {'binary_split': False, 'disable_weighted_vote': False, 'drift_detection_method': 'None', 'grace_period': 50, 'lambda_value': 6, 'leaf_prediction': 'mc', 'max_byte_size': 33554432, 'max_features': 'auto', 'memory_estimate_period': 2000000, 'n_estimators': 10, 'nb_threshold': 0, 'no_preprune': False, 'nominal_attributes': None, 'performance_metric': 'acc', 'random_state': None, 'remove_poor_atts': False, 'split_confidence': 0.01, 'split_criterion': 'gini', 'stop_mem_management': False, 'tie_threshold': 0.1, 'warning_detection_method': 'None'}
# Accuracy: 0.99864000, Precision: 0.99895165, Recall: 0.99819820, F1: 0.99857478
# Evaluating parameters: {'binary_split': False, 'disable_weighted_vote': False, 'drift_detection_method': 'None', 'grace_period': 50, 'lambda_value': 6, 'leaf_prediction': 'mc', 'max_byte_size': 33554432, 'max_features': 'auto', 'memory_estimate_period': 2000000, 'n_estimators': 10, 'nb_threshold': 0, 'no_preprune': False, 'nominal_attributes': None, 'performance_metric': 'acc', 'random_state': None, 'remove_poor_atts': False, 'split_confidence': 0.01, 'split_criterion': 'hellinger', 'stop_mem_management': False, 'tie_threshold': 0.05, 'warning_detection_method': 'None'}
# Accuracy: 0.99596000, Precision: 0.99618369, Recall: 0.99534884, F1: 0.99576609
# Evaluating parameters: {'binary_split': False, 'disable_weighted_vote': False, 'drift_detection_method': 'None', 'grace_period': 50, 'lambda_value': 6, 'leaf_prediction': 'mc', 'max_byte_size': 33554432, 'max_features': 'auto', 'memory_estimate_period': 2000000, 'n_estimators': 10, 'nb_threshold': 0, 'no_preprune': False, 'nominal_attributes': None, 'performance_metric': 'acc', 'random_state': None, 'remove_poor_atts': False, 'split_confidence': 0.01, 'split_criterion': 'hellinger', 'stop_mem_management': False, 'tie_threshold': 0.1, 'warning_detection_method': 'None'}
# Accuracy: 0.99708000, Precision: 0.99706610, Recall: 0.99681542, F1: 0.99694074
# Evaluating parameters: {'binary_split': False, 'disable_weighted_vote': False, 'drift_detection_method': 'None', 'grace_period': 50, 'lambda_value': 6, 'leaf_prediction': 'mc', 'max_byte_size': 33554432, 'max_features': 'auto', 'memory_estimate_period': 2000000, 'n_estimators': 10, 'nb_threshold': 0, 'no_preprune': False, 'nominal_attributes': None, 'performance_metric': 'acc', 'random_state': None, 'remove_poor_atts': False, 'split_confidence': 0.05, 'split_criterion': 'info_gain', 'stop_mem_management': False, 'tie_threshold': 0.05, 'warning_detection_method': 'None'}
# Accuracy: 0.99774000, Precision: 0.99777852, Recall: 0.99748586, F1: 0.99763217
# Evaluating parameters: {'binary_split': False, 'disable_weighted_vote': False, 'drift_detection_method': 'None', 'grace_period': 50, 'lambda_value': 6, 'leaf_prediction': 'mc', 'max_byte_size': 33554432, 'max_features': 'auto', 'memory_estimate_period': 2000000, 'n_estimators': 10, 'nb_threshold': 0, 'no_preprune': False, 'nominal_attributes': None, 'performance_metric': 'acc', 'random_state': None, 'remove_poor_atts': False, 'split_confidence': 0.05, 'split_criterion': 'info_gain', 'stop_mem_management': False, 'tie_threshold': 0.1, 'warning_detection_method': 'None'}
# Accuracy: 0.99796000, Precision: 0.99828056, Recall: 0.99744396, F1: 0.99786208
# Evaluating parameters: {'binary_split': False, 'disable_weighted_vote': False, 'drift_detection_method': 'None', 'grace_period': 50, 'lambda_value': 6, 'leaf_prediction': 'mc', 'max_byte_size': 33554432, 'max_features': 'auto', 'memory_estimate_period': 2000000, 'n_estimators': 10, 'nb_threshold': 0, 'no_preprune': False, 'nominal_attributes': None, 'performance_metric': 'acc', 'random_state': None, 'remove_poor_atts': False, 'split_confidence': 0.05, 'split_criterion': 'gini', 'stop_mem_management': False, 'tie_threshold': 0.05, 'warning_detection_method': 'None'}
# Accuracy: 0.99872000, Precision: 0.99903552, Recall: 0.99828200, F1: 0.99865862
# Evaluating parameters: {'binary_split': False, 'disable_weighted_vote': False, 'drift_detection_method': 'None', 'grace_period': 50, 'lambda_value': 6, 'leaf_prediction': 'mc', 'max_byte_size': 33554432, 'max_features': 'auto', 'memory_estimate_period': 2000000, 'n_estimators': 10, 'nb_threshold': 0, 'no_preprune': False, 'nominal_attributes': None, 'performance_metric': 'acc', 'random_state': None, 'remove_poor_atts': False, 'split_confidence': 0.05, 'split_criterion': 'gini', 'stop_mem_management': False, 'tie_threshold': 0.1, 'warning_detection_method': 'None'}
# Accuracy: 0.99860000, Precision: 0.99899342, Recall: 0.99807249, F1: 0.99853274
# Evaluating parameters: {'binary_split': False, 'disable_weighted_vote': False, 'drift_detection_method': 'None', 'grace_period': 50, 'lambda_value': 6, 'leaf_prediction': 'mc', 'max_byte_size': 33554432, 'max_features': 'auto', 'memory_estimate_period': 2000000, 'n_estimators': 10, 'nb_threshold': 0, 'no_preprune': False, 'nominal_attributes': None, 'performance_metric': 'acc', 'random_state': None, 'remove_poor_atts': False, 'split_confidence': 0.05, 'split_criterion': 'hellinger', 'stop_mem_management': False, 'tie_threshold': 0.05, 'warning_detection_method': 'None'}
# Accuracy: 0.99670000, Precision: 0.99623116, Recall: 0.99685732, F1: 0.99654414
# Evaluating parameters: {'binary_split': False, 'disable_weighted_vote': False, 'drift_detection_method': 'None', 'grace_period': 50, 'lambda_value': 6, 'leaf_prediction': 'mc', 'max_byte_size': 33554432, 'max_features': 'auto', 'memory_estimate_period': 2000000, 'n_estimators': 10, 'nb_threshold': 0, 'no_preprune': False, 'nominal_attributes': None, 'performance_metric': 'acc', 'random_state': None, 'remove_poor_atts': False, 'split_confidence': 0.05, 'split_criterion': 'hellinger', 'stop_mem_management': False, 'tie_threshold': 0.1, 'warning_detection_method': 'None'}
# Accuracy: 0.99698000, Precision: 0.99669068, Recall: 0.99698303, F1: 0.99683684
# Evaluating parameters: {'binary_split': False, 'disable_weighted_vote': False, 'drift_detection_method': 'None', 'grace_period': 50, 'lambda_value': 6, 'leaf_prediction': 'mc', 'max_byte_size': 33554432, 'max_features': 'auto', 'memory_estimate_period': 2000000, 'n_estimators': 10, 'nb_threshold': 0, 'no_preprune': False, 'nominal_attributes': None, 'performance_metric': 'acc', 'random_state': None, 'remove_poor_atts': False, 'split_confidence': 0.1, 'split_criterion': 'info_gain', 'stop_mem_management': False, 'tie_threshold': 0.05, 'warning_detection_method': 'None'}
# Accuracy: 0.99828000, Precision: 0.99853243, Recall: 0.99786298, F1: 0.99819759
# Evaluating parameters: {'binary_split': False, 'disable_weighted_vote': False, 'drift_detection_method': 'None', 'grace_period': 50, 'lambda_value': 6, 'leaf_prediction': 'mc', 'max_byte_size': 33554432, 'max_features': 'auto', 'memory_estimate_period': 2000000, 'n_estimators': 10, 'nb_threshold': 0, 'no_preprune': False, 'nominal_attributes': None, 'performance_metric': 'acc', 'random_state': None, 'remove_poor_atts': False, 'split_confidence': 0.1, 'split_criterion': 'info_gain', 'stop_mem_management': False, 'tie_threshold': 0.1, 'warning_detection_method': 'None'}
# Accuracy: 0.
}
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 14
#      11 # Update the classifier with the current parameters
#      12 arf = AdaptiveRandomForestClassifier(**params)
# ---> 14 accuracy, precision, recall, f1 = run_prequential(
#      15     classifier=arf,
#      16     stream=data_loader,
#      17     feature_selector=None,  # No feature selector
#      18     n_pretrain=200
#      19 )
#      20 print(f"Accuracy: {accuracy:.8f}, Precision: {precision:.8f}, Recall: {recall:.8f}, F1: {f1:.8f}")
#      22 if (accuracy + precision + recall + f1) / 4 > best_score:
#
# File c:\Users\Jamielane Figueroa\Documents\GitHub\QUICaid\tuning\prequential.py:43, in run_prequential(classifier, stream, feature_selector, n_pretrain)
#      40     y_pred = classifier.predict(X)
#      42     # Train incrementally
# ---> 43     classifier.partial_fit(copy.copy(X), [y[0]])
#      45 if y_pred == y:
#      46     correct_predictions += 1
#
# File c:\Users\Jamielane Figueroa\AppData\Local\Programs\Python\Python39\lib\site-packages\skmultiflow\meta\adaptive_random_forests.py:313, in AdaptiveRandomForestClassifier.partial_fit(self, X, y, classes, sample_weight)
#     311         if weight[i] != 0.0:
#     312             self._train_weight_seen_by_model += weight[i]
# --> 313             self._partial_fit(X[i], y[i], self.classes, weight[i])
#     315 return self
#
# File c:\Users\Jamielane Figueroa\AppData\Local\Programs\Python\Python39\lib\site-packages\skmultiflow\meta\adaptive_random_forests.py:324, in AdaptiveRandomForestClassifier._partial_fit(self, X, y, classes, sample_weight)
#     321     self._init_ensemble(X)
#     323 for i in range(self.n_estimators):
# --> 324     y_predicted = self.ensemble[i].predict(np.asarray([X]))
#     325     self.ensemble[i].evaluator.add_result(y_predicted, y, sample_weight)
#     326     k = self._random_state.poisson(self.lambda_value)
#
# File c:\Users\Jamielane Figueroa\AppData\Local\Programs\Python\Python39\lib\site-packages\skmultiflow\meta\adaptive_random_forests.py:609, in ARFBaseLearner.predict(self, X)
#     608 def predict(self, X):
# --> 609     return self.classifier.predict(X)
#
# File c:\Users\Jamielane Figueroa\AppData\Local\Programs\Python\Python39\lib\site-packages\skmultiflow\trees\hoeffding_tree.py:487, in HoeffdingTreeClassifier.predict(self, X)
#     485 r, _ = get_dimensions(X)
#     486 predictions = []
# --> 487 y_proba = self.predict_proba(X)
#     488 for i in range(r):
#     489     index = np.argmax(y_proba[i])
#
# File c:\Users\Jamielane Figueroa\AppData\Local\Programs\Python\Python39\lib\site-packages\skmultiflow\trees\hoeffding_tree.py:526, in HoeffdingTreeClassifier.predict_proba(self, X)
#     524 # Set result as np.array
#     525 if self.classes is not None:
# --> 526     predictions = np.asarray(predictions)
#     527 else:
#     528     # Fill missing values related to unobserved classes to ensure we get a 2D array
#     529     predictions = np.asarray(list(itertools.zip_longest(*predictions, fillvalue=0.0))).T
#
# KeyboardInterrupt:

# %%
# Save results to CSV
df = pd.DataFrame(results)
df.to_csv("arf-tuning.csv", index=False)

print("Grid Search Completed.")
print(f"Best Parameters: {best_params}")
print(f"Best Metrics: {best_metrics}")
print("Results saved to arf-tuning.csv")
